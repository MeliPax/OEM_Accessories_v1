# %%
import pandas as pd

from typing import List, Dict, Tuple

import os
import json

# %%
# read an excel and find all the sheet names
excel_file = pd.ExcelFile(r'..\database\raw_data\HYUNDAI NOV25.xlsx')

# %%
all_sheets_names = excel_file.sheet_names

# %%
# keyword_bridge = {
#     "pref": "preferred",
#     "preferred": "preferred",
#     '2.5T': '2.5T', 
#     '3.3T': '3.3T', 
#     '3.5T' : '3.5T', 
#     '5P':'5P', 
#     '7P':'7P',
#     'AWD':'AWD', 
#     'Adv':'Adv', 
#     'Advanced':'Advanced', 
#     'Black':'Black',
#     'Calli':'Calligraphy', 
#     'Calligraphy':'Calligraphy', 
#     'Coupe':'Coupe', 
#     'Ed':'Edition', 
#     'Ess': 'Essential', 
#     'Essential':'Essential', 
#     'HEV':'Hybrid', 
#     'Hybrid':'Hybrid', 
#     'ICE':'ICE', 
#     'LR':'Long Range', 
#     'Lux': 'Luxury', 
#     'Luxury':'Luxury',
#     'N':'N', 
#     'N-Line':'N-Line', 
#     'NHL':'NHL', 
#     'PHEV':'Plug-In Hybrid',
#     'Plug-In Hybrid':'Plug-In Hybrid', 
#     'Performance':'Performance', 
#     'Pkg':'Pkg', 
#     'Plus':'Plus', 
#     'Prestige':'Prestige', 
#     'Long':'Long',
#     'Range':'Range', 
#     'Sport':'Sport', 
#     'Tech':'Tech', 
#     'Trend':'Trend', 
#     'Ult':'Ult', 
#     'Ultimate':'Ultimate', 
#     'Urban':'Urban', 
#     'XRT':'XRT', 
#     'e-SC':'e-SC', 
#     'eLSD':'eLSD',
#     'IVT':'IVT',
#     'EV': 'Electric',
#     'Electric':'Electric',
#     'GT':'GT',
#     'Turbo':'Turbo',
#     'Manual':'Manual',
#     'Night':'Night',
#     'DCT':'DCT',
#     '2.0L':'2.0L', 
#     'LE':'LE', 
#     'FWD':'FWD',
#     'Plug-In':'Plug-In'

# }

# %%
def load_key_words():
    print(os.path.exists(r'..\database\keywords_db\tokenized_key_words.json'))

    with open(r'..\database\keywords_db\tokenized_key_words.json', 'r') as file:
        keyword_bridge = json.load(file)
        keyword_bridge = (lambda obj: {k.lower(): (v.lower() if isinstance(v, str) else v) for k, v in obj.items()})(keyword_bridge)
    return keyword_bridge
keyword_bridge = load_key_words()
# Out:
# True

# %%
# model_name_exceptions = {
#     "EV": "EV",
#     "Electric":"EV"
# }

model_exceptions_for_naming_conventions = ["G80 EV","G70 EV", "Kona EV"]

# %%
modelNum_identifier_key_words = ["HEV", "Hybrid", "EV", "Electric", "Plug-In Hybrid", "PHEV", "Essential"] 


un_necessary_key_words = ["Pref", "Urban", "Calli", "ICE", ]

# %%
def tag_ice_veh(df):
    # print(df.columns)
    
    list_to_tag_df = df[(~df["Trim"].str.contains(r"Hybrid|Electric|Plug-in|\bEV\b|PHEV|HEV|EV", case=False, na=False))
             & (~df["Tags"].str.contains(r"Hybrid|Electric|Plug-in", case=False, na=False))
             & (~df["Model"].str.contains(r"Hybrid|Electric|Plug-in", case=False, na=False))
             & (~df["source_modelName"].str.contains(r"Hybrid|Electric|Plug-in", case=False, na=False))
             ]
    
    mask = (
        (df["ModelNumber"].isin(list_to_tag_df["ModelNumber"])) &
        (df["Model"].isin(list_to_tag_df["Model"])) &
        (df["Year"].isin(list_to_tag_df["Year"]))
    )

    df.loc[mask, "Tags"] = df.loc[mask, "Tags"] + ", ice"
    
    return df

def normalize(text: str) -> str:
    """Normalize text for case-insensitive matching."""
    return text.strip().lower()

def ensure_columns(df: pd.DataFrame) -> pd.DataFrame:
    """Ensure required columns exist."""
    if 'Fixed_model' not in df.columns:
        df['Fixed_model'] = ''
    if 'Tags' not in df.columns:
        df['Tags'] = ''
    return df

def tokenize(text: str) -> List[str]:
    """Split text into tokens by spaces only, preserving hyphenated words."""
    clean_text = text.replace('(', '').replace(')', '').replace('/', ' ')
    tokens = clean_text.split()  # split only on spaces
    return [normalize(token) for token in tokens if token]

def to_camel_case_with_spaces(text: str) -> str:
    """Convert each word to CamelCase but keep spaces (e.g., 'kona ev' -> 'Kona EV')."""
    return ' '.join(word.capitalize() for word in text.split())

def process_row(model: str, trim: str, keyword_bridge: dict, exceptions: list) -> tuple:
    """
    Process a model and trim string to:
    1. Remove keywords from the model name if they exist in keyword_bridge.
    2. Collect tags from both model and trim based on keyword_bridge.
    3. Return a tuple of (cleaned model name in CamelCase, comma-separated tags in CamelCase).

    Rules:
    - If model is in exceptions (normalized), keep it unchanged.
    - For other models, remove words that match keyword_bridge keys.
    - Tags are collected from both model and trim words that match keyword_bridge.
    """
    normalized_bridge = {normalize(k): v for k, v in keyword_bridge.items()}   

    # All values in Normalized_bride are not in lowercase, need to find out why . I had to change edition to lower in the tockenized_key_db for a quick fix. 
    # something to investigate.

    normalized_exceptions = [normalize(e) for e in exceptions]
    tags_set = set()

    # Normalize model for exception check
    model_normalized = normalize(model)

    # Process model
    words_model = tokenize(model)
    if model_normalized in normalized_exceptions:
        fixed_model = model  # keep original if in exceptions
    else:
        fixed_words = []
        for word in words_model:
            # print(f"Testing: word_cath: {normalize(word) in normalized_bridge}")
            if normalize(word) in normalized_bridge:
                tags_set.add(normalized_bridge[normalize(word)])
                # Skip adding this word to fixed_model because it's a keyword
            else:
                fixed_words.append(word)
        fixed_model = ' '.join(fixed_words)

    # Convert fixed_model to CamelCase with spaces
    fixed_model = to_camel_case_with_spaces(fixed_model)

    # Process Trim
    words_trim = tokenize(trim)
    for word in words_trim:
        if normalize(word) in normalized_bridge:                
            tags_set.add(normalized_bridge[normalize(word)])

    # Convert tags to CamelCase
    tags = ', '.join(sorted(to_camel_case_with_spaces(tag) for tag in tags_set))
    
    
    return fixed_model, tags



def apply_processing(df: pd.DataFrame, keyword_bridge: Dict[str, str], exceptions: List[str]) -> pd.DataFrame:

    keyword_bridge = load_key_words()
    if not {'Model', 'Trim'}.issubset(df.columns):
        raise KeyError("DataFrame must contain 'Model' and 'Trim' columns.")
    
    # Preprocessing: Standardize Electric -> EV in Model column
    df['Model'] = df['Model'].str.replace(r'\bElectric\b', 'EV', case=False, regex=True)

    df = ensure_columns(df)
    
    new_df = df.copy()
    for idx, row in new_df.iterrows():
        fixed_model, tags = process_row(row['Model'], row['Trim'], keyword_bridge, exceptions)
        new_df.at[idx, 'Fixed_model'] = fixed_model
        new_df.at[idx, 'Tags'] = tags

    new_df.rename(columns={'Model':'source_modelName', 'Fixed_model':'Model'}, inplace=True)

    # Hyundai sheet come with key word ICE in the trime name but our sheet doesn't add that keyword.
    # to handle this, we could choose to, after cleaning our data, we could loop through the list and heck those that don't have any hybrid or Ev lable, and add an ICe tag across the database. That would solve th issue without having to do lot of manoeuver

    # adding IC tag to to our model number database before saving it

    new_df = tag_ice_veh(new_df)

    return new_df

# %%
tokenize("1.6T Ultimate Calligraphy HEV 6P Special Edition (NHL)")
# Out:
# ['1.6t', 'ultimate', 'calligraphy', 'hev', '6p', 'special', 'edition', 'nhl']

# %%
process_row("Santa Fe", "1.6T Ultimate Calligraphy HEV 6P Special Edition (NHL)", keyword_bridge, model_exceptions_for_naming_conventions)
# Out:
# ('Santa Fe', 'Calligraphy, Edition, Hybrid, Nhl, Ultimate')

# %%
# model_df_dict = pd.read_excel(r'..\database\raw_data\HYUNDAI NOV25.xlsx')


# Read all sheets into a dictionary
model_df_dict = pd.read_excel(r'..\database\raw_data\HYUNDAI NOV25.xlsx', sheet_name = None)

# Combine sheets and add sheet_name column
combined_df = pd.concat(
    [df.assign(sheet_name=sheet_name) for sheet_name, df in model_df_dict.items()],
    ignore_index=True
)

# %%
def clean_model_column(df):

    # 1. Remove tabs and trim whitespace
    df["Model"] = df["Model"].str.replace(r"\t", "", regex=True).str.strip()

    
    # Preprocessing: Standardize Electric -> EV in model column
    df['Model'] = df['Model'].str.replace(r'\bElectric\b', 'EV', case=False, regex=True)
    


    return df


def clean_Trim_column(df):

    # 1. Remove tabs and trim whitespace
    df["Trim"] = df["Trim"].str.replace(r"\t", "", regex=True).str.strip()

    
    # Preprocessing: Standardize Electric -> EV in Trim column
    df['Trim'] = df['Trim'].str.replace(r'\bN Line\b', 'N-Line', case=False, regex=True)
    df['Trim'] = df['Trim'].str.replace(r'\bPreferred-Trend\b', 'Preferred Trend', case=False, regex=True)
    df['Trim'] = df['Trim'].str.replace(r'\bLR\b', 'Long Range', case=False, regex=True)

    
    
    return df

# %%
def clean_df(df: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
    # Select and rename columns
    df = df[["Model", "Description ", "Description", "Description 2", "sheet_name"]].copy()
    df.columns = ['ModelNumber', 'Model1', 'Model2', 'Trim', 'Source_sheets']

    # Fill missing Model1 with Model2
    df["Model1"] = df["Model1"].fillna(df["Model2"])
    df.drop(columns=["Model2"], inplace=True)

    # Clean ModelNumber and Trim
    df["ModelNumber"] = df["ModelNumber"].str.replace(r"\t", "", regex=True)
    df["Trim"] = df["Trim"].str.replace(r"\t", "", regex=True)

    # Standardize spelling: Caligraphy -> Calligraphy
    df["Trim"] = df["Trim"].str.replace(r"\bCaligraphy\b", "Calligraphy", case=False, regex=True)

    # Drop rows with null ModelNumber
    df.dropna(subset=["ModelNumber"], inplace=True)

    # Extract Year from Source_sheets
    df["Year"] = df["Source_sheets"].str.extract(r"(\b\d{4}\b)").astype("Int64")
    df = df[["Year", "ModelNumber", "Model1", "Trim", "Source_sheets"]]
    df.columns = ["Year", "ModelNumber", "Model", "Trim", "Source_sheets"]

    # Remove duplicates based on ModelNumber, Model, Source_sheets
    df.drop_duplicates(subset=["ModelNumber", "Model", "Source_sheets"], inplace=True)

    # Normalize ModelNumber
    df["ModelNumber"] = (
        df["ModelNumber"]
        .astype(str)
        .str.strip()
        .str.upper()
        .str.replace(r"\s+", "", regex=True)
        .str.replace(r"[^\x00-\x7F]+", "", regex=True)  # Remove non-printable chars
    )

    # Drop duplicates based on ModelNumber and Year
    df.drop_duplicates(subset=["ModelNumber", "Year"], inplace=True)

    # Apply custom cleaning for Model column
    df = clean_model_column(df)
    df = clean_Trim_column(df)
    # Identify duplicates for reporting
    duplicates = (
        df[df.duplicated(subset=["ModelNumber", "Year"], keep=False)]
        .assign(DuplicateCount=lambda x: x.groupby(["ModelNumber", "Year"])["ModelNumber"].transform("count"))
        .sort_values(by="DuplicateCount", ascending=False)
    )

    return df, duplicates



# cleaned_models[(cleaned_models["Model1"]=="Tucson HEV") 
#             & (cleaned_models["Source_sheets"].str.contains("2024", case=False))
#             ]


# cleaned_models[(cleaned_models["Model"]=="Tucson HEV") 
#             & (cleaned_models["Source_sheets"].str.contains("2024", case=False))
#             ]

# %%
# 
cleaned_models, duplicates = clean_df(combined_df)

processed_df = apply_processing(cleaned_models, keyword_bridge, model_exceptions_for_naming_conventions)
# Out:
# True

# %%
# processed_df.to_csv(r'..\database\dbs\Hyundai_models_db.csv', index=False)

# %%
processed_df[(processed_df["Model"]=='Santa Fe') 
                    & (processed_df["Year"]==2024)
                    # & (processed_df["Trim"]=="Luxury HEV")
                    # & (processed_df["Tags"].str.contains("hybrid"))
                    ]

# cleaned_models[(cleaned_models["Model"]=="Tucson HEV") 
#             & (cleaned_models["Source_sheets"].str.contains("2024", case=False))
#             ]

# process_row("Tucson HEV", "N-Line HEV", keyword_bridge, model_exceptions_for_naming_conventions)
# Out:
#      Year   ModelNumber source_modelName  \
# 245  2024  SAHW7G1APRHE  Santa Fe Hybrid
# 246  2024  SAHW7G1APRTH  Santa Fe Hybrid
# 247  2024  SAHW6G1AULCS  Santa Fe Hybrid
# 248  2024  SACW7N2DXR00         Santa Fe
# 249  2024  SACW7N2DLU00         Santa Fe
# 250  2024  SACW6N2DULBG         Santa Fe
# 251  2024  SACW6N2DULBH         Santa Fe
# 313  2024  SA5SAA16G2AA  Santa Fe Hybrid
# 314  2024  SA5SAA16G2AD  Santa Fe Hybrid
# 315  2024  SA5SAA16G4BI  Santa Fe Hybrid
# 316  2024  SA5SDA25DN00         Santa Fe
# 317  2024  SA5SDA25D300         Santa Fe
# 318  2024  SA5SDA25D4BG         Santa Fe
# 319  2024  SA5SDA25D4BH         Santa Fe
#
#                                                   Trim Source_sheets  \
# 245                   1.6T Preferred Hybrid AWD 7-Pass          2024
# 246       1.6T Preferred Hybrid w/Trend Pkg AWD 7-Pass          2024
# 247  1.6T Ultimate Calligraphy HEV 6P Special Editi...          2024
# ...

# %%
def get_duplicates(df):
    # Show rows where ModelNumber, Model, and Source_sheets are all duplicated
    duplicates = cleaned_models[cleaned_models.duplicated(subset=["ModelNumber", "Model", "Source_sheets"], keep=False)]

    # Sort by frequency of these combined duplicates
    duplicates["DuplicateCount"] = duplicates.groupby(["ModelNumber", "Model", "Source_sheets"])["ModelNumber"].transform("count")
    duplicates = duplicates.sort_values(by="DuplicateCount", ascending=False)
    
    return duplicates
get_duplicates(processed_df)
# Out:
# Empty DataFrame
# Columns: [Year, ModelNumber, Model, Trim, Source_sheets, Fixed_model, Tags, DuplicateCount]
# Index: []

# %%
processed_df[(processed_df["Model"]=='Tucson') 
                    & (processed_df["Year"]==2024)
                    & (processed_df["Trim"]=="N-Line")

                    # & (processed_df["Tags"].str.contains("calligraphy"))
                    ]
# Out:
# Empty DataFrame
# Columns: [Year, ModelNumber, source_modelName, Trim, Source_sheets, Model, Tags]
# Index: []

# %%
# processed_df.to_csv(r'..\database\dbs\Hyundai_models_db.csv', index=False)

# %%
def search_vehicle_by_year_and_model(year, model):
    # Filter the DataFrame based on year and model
    filtered_df = cleaned_models[
        (cleaned_models['Year'] == year) & 
        (cleaned_models['Model'].str.contains(model, case=False, na=False))
    ]
    return filtered_df


def search_vehicle_by_model(model):
    # Filter the DataFrame based on model
    filtered_df = cleaned_models[ 
        (cleaned_models['Model'].str.contains(model, case=False, na=False))
    ]
    return filtered_df

def search_vehicle_by_model_and_trim_keyword(model, trim_search_key):
    # Filter the DataFrame based on model and trim key 
    filtered_df = cleaned_models[ 
        (cleaned_models['Model'].str.contains(model, case=False, na=False)) 
        & (cleaned_models['Trim'].str.contains(trim_search_key, case=False, na=False))
    ]
    return filtered_df

# %%
combined_df.columns.to_list()
# Out:
# ['Model',
#  'Description ',
#  'Description 2',
#  'CPR',
#  'TCPR',
#  'LR',
#  'FI',
#  'FLRR',
#  'SF1-24',
#  'SF25-36',
#  'SF37-48',
#  'SF49-60',
#  'SF61-72',
#  'SF73-84',
#  'BF60-84',
#  'SF85-96',
#  'SRF12-24',
#  'SRF25-36',
#  'SRF37-48',
#  'SRF49-60',
#  'SRF61-72',
#  'SRF73-84',
#  'SRF85-96',
#  'SRBF60-84',
#  'NPFI',
#  'NPRR',
#  'T6NR24-72',
#  'T5NR24-84',
#  'T4NR24-84',
#  'T3NR24-84',
#  'T2NR24-96',
#  'LI',
#  'LLRR',
#  'SL24',
#  'SL33',
#  'SL36',
#  'SL39',
#  'SL48',
#  'SL60',
#  'SRL36',
#  'SRL48',
#  'SRL60',
#  'RV24',
#  'RV33',
#  'RV36',
#  'RV39',
#  'RV48',
#  'RV60',
#  'MAR',
#  'sheet_name',
#  'SL1-35',
#  'SRL1-35',
#  'TACR1-24',
#  'TACR25-36',
#  'TACR37-48',
#  'TACR49-60',
#  'TACR61-72',
#  'TACR73-84',
#  'TACBR60-84',
#  'Column1',
#  'TCCR1-24',
#  'TCCR25-36',
#  'TCCR37-48',
#  'TCCR49-60',
#  'TCCR61-72',
#  'TCCR73-84',
#  'TCCBR60-84',
#  'CLRR',
#  'CT3SR24-84',
#  'CT4SR24-84',
#  'CT5SR24-84',
#  'CT6SR24-84',
# ...

# %%
# print (combined_df.columns)

# %%
combined_df[(combined_df["Description "]=="Tucson") 
            & (combined_df["sheet_name"].str.contains("2024", case=False))
            ]
# Out:
#               Model Description  Description 2 CPR  TCPR LR FI FLRR SF1-24  \
# 239  TUCWDK2EPR00\t       Tucson     Preferred   -   NaN  -  -    -      -
# 240  TUCWDK2EPRTR\t       Tucson         Trend   -   NaN  -  -    -      -
# 307    TU4SAA25B200       Tucson     Preferred   -   NaN  -  -    -      -
# 308    TU4SAA25B241       Tucson         Trend   -   NaN  -  -    -      -
#
#     SF25-36  ... TCCR49-60 TCCR61-72 TCCR73-84 TCCBR60-84 CLRR CT3SR24-84  \
# 239       -  ...       NaN       NaN       NaN        NaN  NaN        NaN
# 240       -  ...       NaN       NaN       NaN        NaN  NaN        NaN
# 307       -  ...       NaN       NaN       NaN        NaN  NaN        NaN
# 308       -  ...       NaN       NaN       NaN        NaN  NaN        NaN
#
#      CT4SR24-84  CT5SR24-84  CT6SR24-84  Description
# 239         NaN         NaN         NaN          NaN
# 240         NaN         NaN         NaN          NaN
# 307         NaN         NaN         NaN          NaN
# ...

# %%
processed_df[(processed_df["Model"]=="Tucson") 
             & (processed_df["Year"]==2024)
             ]
# Out:
#      Year   ModelNumber source_modelName           Trim Source_sheets   Model  \
# 239  2024  TUCWDK2EPR00           Tucson      Preferred          2024  Tucson
# 240  2024  TUCWDK2EPRTR           Tucson          Trend          2024  Tucson
# 241  2024  TUHWDG1ALUHE       Tucson HEV     Luxury HEV          2024  Tucson
# 242  2024  TUHWDG1ANLHE       Tucson HEV     N-Line HEV          2024  Tucson
# 243  2024  TUHWDG1AULHE       Tucson HEV   Ultimate HEV          2024  Tucson
# 244  2024  TUPWDG1AULPH      Tucson PHEV  Ultimate PHEV          2024  Tucson
# 307  2024  TU4SAA25B200           Tucson      Preferred    2024 (old)  Tucson
# 308  2024  TU4SAA25B241           Tucson          Trend    2024 (old)  Tucson
# 309  2024  TU4SAA16G3AA       Tucson HEV     Luxury HEV    2024 (old)  Tucson
# 310  2024  TU4SAA16GOAA       Tucson HEV     N-Line HEV    2024 (old)  Tucson
# 311  2024  TU4SAA16G4AA       Tucson HEV   Ultimate HEV    2024 (old)  Tucson
# ...

# %%
def search_model_y_m_t(Year, Model, Trim):
    return processed_df[
        (1==1)
        &(processed_df["Year"] == Year)
        &(processed_df["Model"] == Model)
        &(processed_df["Trim"].str.contains(Trim, case=False))
        ]

# %%
search_model_y_m_t(2024,'Tucson', 'N-Line')
# Out:
#      Year   ModelNumber source_modelName        Trim Source_sheets   Model  \
# 242  2024  TUHWDG1ANLHE       Tucson HEV  N-Line HEV          2024  Tucson
# 310  2024  TU4SAA16GOAA       Tucson HEV  N-Line HEV    2024 (old)  Tucson
#
#                Tags
# 242  Hybrid, N-line
# 310  Hybrid, N-line
