# %%
import pandas as pd
from engine import load_env, create_engine_from_env
from models.manufacture_module import get_manufacturer_df, get_active_unique_manufacturers, get_manufacturer_bulletins_json, print_bulletin_details, convert_bulletin_to_df, save_vehicle_models_to_csv, batch_save_manufacturer_models, search_models_by_description

# %%
import json
from typing import Union, Any

def parse_json_string(json_string: str) -> Union[dict, list]:
    """
    Parse a JSON string into a Python object (dict or list).

    Args:
        json_string (str): A valid JSON string.

    Returns:
        dict or list: Parsed JSON object.

    Raises:
        ValueError: If the input is not valid JSON.
        TypeError: If input is not a string.
    """
    if not isinstance(json_string, str):
        raise TypeError("Input must be a JSON string")

    try:
        return json.loads(json_string)
    except json.JSONDecodeError as exc:
        raise ValueError(f"Invalid JSON string: {exc}") from exc

# %%
# Loaded environment variables and created database engine
load_env()
engine = create_engine_from_env()

# %%
# Batch save vehicle models for specified manufacturers
# manufactures = ["Hyundai","Honda","Kia","Mazda","Subaru","Toyota","Volkswagen"]
# manufactures = ["Mitsubishi"]
# batch_save_manufacturer_models(engine, manufactures)

# %%
model_number_db = pd.read_csv("db/db_vehicle_models.csv")

# %%
make_df = model_number_db[model_number_db["Manufacturer"] == "Mazda"]

# %%
make_df[
    
    (make_df["ModelYear"]==2026)
    # (1==1)
    &(make_df["Description"].str.contains("CX-30", case=False, na=False))
    # & (make_df["Description"].str.contains("Cross", case=False, na=False))
    # & (make_df["Description"].str.contains("noir", case=False, na=False))
    & (make_df["Package"]=="KE00")
    ]
# Out:
#      Manufacturer  ModelYear ModelNumber  \
# 2219        Mazda       2026      ZXSL86
# 2222        Mazda       2026      ZXTM86
#
#                                             Description  Description2 Package  \
# 2219          CX-30 GS Kuro AT AWD CX-30 GS Kuro AT AWD           NaN    KE00
# 2222  CX-30 GT Kuro AT AWD, Turbo CX-30 GT Kuro AT A...           NaN    KE00
#
#      Style_ID
# 2219      NaN
# 2222      NaN

# %%
make_df
# Out:
#      Manufacturer  ModelYear ModelNumber  \
# 1872        Mazda       2020      HVXK60
# 1873        Mazda       2020      HVXK80
# 1874        Mazda       2020      HVSK80
# 1875        Mazda       2020      HXXK80
# 1876        Mazda       2020      HXSK80
# ...           ...        ...         ...
# 2257        Mazda       2026      L3PK66
# 2258        Mazda       2026      L3PK86
# 2259        Mazda       2026      L3TK66
# 2260        Mazda       2026      L3TK66
# 2261        Mazda       2026      L3TK86
#
#                                        Description  Description2 Package  \
# 1872                            CX-3 GX Manual FWD           NaN     NaN
# 1873                              CX-3 GX Auto FWD           NaN     NaN
# 1874                              CX-3 GS Auto FWD           NaN     NaN
# 1875                              CX-3 GX Auto AWD           NaN     NaN
# 1876                              CX-3 GS Auto AWD           NaN     NaN
# ...                                            ...           ...     ...
# 2257     MX-5 RF GS-P 6MT GS-P - 6MT Sport Package           NaN    SP00
# 2258                   MX-5 RF GS-P 6AT GS-P - 6AT           NaN    AA00
# 2259                       MX-5 RF GT 6MT GT - 6MT           NaN    AA00
# 2260  MX-5 RF GT 6MT GT - 6MT, Grand Sport Package           NaN    GR00
# 2261                       MX-5 RF GT 6AT GT - 6AT           NaN    AA00
#
#      Style_ID
# 1872      NaN
# 1873      NaN
# 1874      NaN
# 1875      NaN
# 1876      NaN
# ...       ...
# 2257      NaN
# 2258      NaN
# 2259      NaN
# 2260      NaN
# 2261      NaN
#
# [390 rows x 7 columns]

# %%
make = "Mitsubishi"
year = 2026
keywords = ["eclipse"]
# keywords = ["outlander","phev", "SE"]
# keywords = ["rvr","sel", "awc"]

search_models_by_description(make, year, keywords)
# Out:
# Empty DataFrame
# Columns: [Manufacturer, ModelYear, ModelNumber, Description, Description2, Package, Style_ID]
# Index: []
