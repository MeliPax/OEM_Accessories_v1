# %%
import sys
import os
from pathlib import Path

import pandas as pd
from engine import load_env, create_engine_from_env
from models.manufacture_module import (
    search_models_by_description,
    save_vehicle_models_to_csv,
    batch_save_manufacturer_models
)

# %%
import json
from typing import Union, Any

def parse_json_string(json_string: str) -> Union[dict, list]:
    """
    Parse a JSON string into a Python object (dict or list).

    Args:
        json_string (str): A valid JSON string.

    Returns:
        dict or list: Parsed JSON object.

    Raises:
        ValueError: If the input is not valid JSON.
        TypeError: If input is not a string.
    """
    if not isinstance(json_string, str):
        raise TypeError("Input must be a JSON string")

    try:
        return json.loads(json_string)
    except json.JSONDecodeError as exc:
        raise ValueError(f"Invalid JSON string: {exc}") from exc

# %%
# Loaded environment variables and created database engine
load_env()
engine = create_engine_from_env()

# %%
# Batch save vehicle models for specified manufacturers
# manufactures = ["Hyundai","Honda","Kia","Mazda","Subaru","Toyota","Volkswagen"]
# manufactures = ["Mitsubishi"]
# batch_save_manufacturer_models(engine, manufactures)

# %%
model_number_db = pd.read_csv("db/db_vehicle_models.csv")

# %%
make_df = model_number_db[model_number_db["Manufacturer"] == "Mitsubishi"]

# %%
# make_df[
    
#     (make_df["ModelYear"]==2026)
#     # (1==1)
#     &(make_df["Description"].str.contains("CX-30", case=False, na=False))
#     # & (make_df["Description"].str.contains("Cross", case=False, na=False))
#     # & (make_df["Description"].str.contains("noir", case=False, na=False))
#     & (make_df["Package"]=="KE00")
#     ]

# %%
make_df[make_df["Description"].str.contains("avail", case=False, na=False)]
# Out:
#      Manufacturer  ModelYear ModelNumber  \
# 3290   Mitsubishi       2019      CE45-B
# 3291   Mitsubishi       2019      CE45-F
# 3292   Mitsubishi       2019      CE45-X
# 3297   Mitsubishi       2019      CE45-F
# 3342   Mitsubishi       2022      CE45-F
# 3343   Mitsubishi       2022      CE45-G
#
#                                         Description  Description2 Package  \
# 3290             Eclipse Cross ES S-AWC *Ltd Avail*           NaN     NaN
# 3291             Eclipse Cross SE S-AWC *Ltd Avail*           NaN     NaN
# 3292             Eclipse Cross GT S-AWC *Ltd Avail*           NaN     NaN
# 3297  Eclipse Cross SE w/Tech Pkg S-AWC *Ltd Avail*           NaN     NaN
# 3342             Eclipse Cross SE S-AWC *Ltd Avail*           NaN     NaN
# 3343            Eclipse Cross SEL S-AWC *Ltd Avail*           NaN     NaN
#
#      Style_ID
# 3290   403358
# 3291   403359
# 3292   403360
# 3297   406541
# 3342   419294
# 3343   419295

# %%
make = "Mitsubishi"
year = 2025
keywords = ['outlander', 'gt', 'prem', 's-awc']
# keywords = ["rvr","se"]
# keywords = ["black"]
# keywords = ["eclipse"]

search_models_by_description(make, year, keywords, exclude_ev=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
