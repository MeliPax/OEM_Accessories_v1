# %%
import pandas as pd

# %%
'''

Create model that pulls the OEM accessories data from AristoBob Server and does the following:

- Produce a list of all the OEM Accessory inventory (Make/Model/Trim, ENG/FR and Year)- > 
    - Export it into an excel sheet and save it as a resource to be used for report 
    - FInd a way to share it with support to check what's live and what missing for incoming calls 
    - Add the OEM accessories Teams chanel for visibility

- Data sanity check: 
    - Check if the data is complete? 
        - Count rows for each and see if aligns with what is expected
        - Cross check to see if the language is accurate
        - Check is the data is allocated to the correct vehicle
    - This helps to make sure that the data that has been loaded is is complete and accurate

- This 


Resources to look at:
    - Entities under the Sql file in the current directory
    - 

'''
# Out:
# "\n\nCreate model that pulls the OEM accessories data from AristoBob Server and does the following:\n\n- Produce a list of all the OEM Accessory inventory (Make/Model/Trim, ENG/FR and Year)- > \n    - Export it into an excel sheet and save it as a resource to be used for report \n    - FInd a way to share it with support to check what's live and what missing for incoming calls \n    - Add the OEM accessories Teams chanel for visibility\n\n- Data sanity check: \n    - Check if the data is complete? \n        - Count rows for each and see if aligns with what is expected\n        - Cross check to see if the language is accurate\n        - Check is the data is allocated to the correct vehicle\n    - This helps to make sure that the data that has been loaded is is complete and accurate\n\n- This \n\n\nResources to look at:\n    - Entities under the Sql file in the current directory\n    - \n\n"
